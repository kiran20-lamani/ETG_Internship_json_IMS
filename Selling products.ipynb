# %%
import json

fd = open("products.json",'r')
r = fd.read()
fd.close()

products = json.loads(r)



print("Welcome to shop")


ui_prod = input("Enter the product Id: ")
ui_quan = int(input("Enter the quantity of the Product: "))

for i in products.keys():
    while ui_prod == i:
        if ui_quan <= products[i]['quan']:
            print("****************************************")
            print("             product:",products[ui_prod]['name'])
            print("               price:",products[ui_prod]['price'])
            print("         Expiry date:",products[ui_prod]['expiry'])
            print(" Manufacturing Brand:",products[ui_prod]['brand'])
            print("****************************************")
            print("----------BILLING DETAILS:---------- ")
            print("Total Amount: ",products[ui_prod]['price']*ui_quan) 
            print("Enjoy Your Day")
            print("Thank You. Visit Again")
            print("**********************************")
            products[ui_prod]["quan"] = products[ui_prod]["quan"] - ui_quan
        else:
            print("Sorry. Stock of product you enterd is: ",products[ui_prod]['quan'],"\nPlease accept our apologies for this inconvenience")
        break
if ui_prod not in products.keys():
    print("Sorry. No product found for ID: ",ui_prod,"\Please enter valid product ID")
    
    
js = json.dumps(products)

fd = open("products.json",'w')
fd.write(js)
fd.close()

## The sold items information is stored on sales.json
fd = open("sales.json",'r')
trans = fd.read()
fd.close()

sales = json.loads(trans)
num = len(sales)+1

sales[num] = {'prod':ui_prod, 'quann' : ui_quan, 'amount': products[ui_prod]['price'] * ui_quan}
sale = json.dumps(sales)

fd = open("sales.json",'w')
fd.write(sale)
fd.close()
# Out:
# Welcome to shop
# Enter the product Id: 1031
# Enter the quantity of the Product: 5
# ****************************************
#              product: Tata Salt
#                price: 20
#          Expiry date: 12 jan 2022
#  Manufacturing Brand: Tata
# ****************************************
# ----------BILLING DETAILS:----------
# Total Amount:  100
# Enjoy Your Day
# Thank You. Visit Again
# **********************************

# %%
products
# Out:
# {'1001': {'name': 'Colgate Maxfresh',
#   'price': 215,
#   'quan': 34,
#   'expiry': '20 jun 2024',
#   'brand': 'Colgate'},
#  '1002': {'name': 'Pepsodent Gum Care',
#   'price': 300,
#   'quan': 146,
#   'expiry': '15 jul 2022',
#   'brand': 'Pepsodent'},
#  '1003': {'name': 'Dabur Amla Hair Oil',
#   'price': 247,
#   'quan': 85,
#   'expiry': '10 aug 2024',
#   'brand': 'DABUR'},
#  '1004': {'name': 'Nivea Men Face Wash',
#   'price': 149,
#   'quan': 90,
#   'expiry': '31 jul 2022',
#   'brand': 'Nivea'},
#  '1005': {'name': 'Himalaya Herbal Face wash',
#   'price': 104,
#   'quan': 200,
#   'expiry': '22 may 2022',
#   'brand': 'Himalaya'},
#  '1006': {'name': 'Himalaya Baby Powder',
#   'price': 243,
#   'quan': 150,
#   'expiry': '31 may 2024',
#   'brand': 'Himalaya'},
#  '1007': {'name': 'Nivea Talcum Powder',
#   'price': 199,
#   'quan': 95,
#   'expiry': '31 may 2024',
#   'brand': 'Nivea'},
#  '1008': {'name': 'Fogg Xtremo Scent',
#   'price': 299,
#   'quan': 145,
#   'expiry': '01 jan 2024',
#   'brand': 'FOGG'},
#  '1009': {'name': 'Villain Perfume men',
#   'price': 555,
#   'quan': 225,
#   'expiry': '31 may 2024',
#   'brand': 'Villian'},
#  '1010': {'name': 'Dairy Milk Silk',
#   'price': 475,
#   'quan': 40,
#   'expiry': '31 jan 2022',
#   'brand': 'Cadbury'},
#  '1011': {'name': 'Kitkat Desert',
#   'price': 55,
#   'quan': 50,
#   'expiry': '31 aug 2022',
#   'brand': 'Nestle'},
#  '1012': {'name': 'Dark Fantasy Choco Fills',
#   'price': 90,
#   'quan': 85,
#   'expiry': '21 feb 2022',
#   'brand': 'Dark Fantasy'},
#  '1013': {'name': 'Candyman Fantasy',
#   'price': 80,
#   'quan': 95,
#   'expiry': '28 dec 2021',
#   'brand': 'Candyman Fantastik'},
#  '1014': {'name': 'Lotte Choco Pie',
#   'price': 110,
#   'quan': 95,
#   'expiry': '01 jun 2022',
#   'brand': 'Lotte'},
#  '1015': {'name': 'Britania Chocolate cake',
#   'price': 120,
#   'quan': 100,
#   'expiry': '15 jul 2022',
#   'brand': 'Britania'},
#  '1016': {'name': 'Pillsbury cookes cake',
#   'price': 90,
#   'quan': 200,
#   'expiry': '02 dec 2021',
#   'brand': 'Pillsbury'},
#  '1017': {'name': 'Kraft Oreo Soft Cake',
#   'price': 249,
#   'quan': 120,
#   'expiry': '30 dec 2021',
#   'brand': 'Ore0'},
#  '1018': {'name': "Mom's Magic Cashew",
#   'price': 80,
#   'quan': 180,
#   'expiry': '19 mar 2022',
#   'brand': 'Sunfeast'},
#  '1019': {'name': 'Cadbury Oreo chacolate',
#   'price': 60,
#   'quan': 185,
#   'expiry': '19 feb 2022',
#   'brand': 'Cadbury'},
#  '1020': {'name': 'Betty Croker Pancake',
#   'price': 346,
#   'quan': 190,
#   'expiry': '15 jan 2022',
#   'brand': 'Betty Croker'},
#  '1021': {'name': 'Parle G Original',
#   'price': 67,
#   'quan': 140,
#   'expiry': '13 dec 2011',
#   'brand': 'Parle'},
#  '1022': {'name': 'Lays Potato Chips',
#   'price': 30,
#   'quan': 450,
#   'expiry': '14 feb 2023',
#   'brand': "Lay's"},
#  '1023': {'name': 'Bingo! Mad Angle',
#   'price': 25,
#   'quan': 440,
#   'expiry': '20 dec 2023',
#   'brand': 'Bingo!'},
#  '1024': {'name': "Kellogg's pringles",
#   'price': 85,
#   'quan': 400,
#   'expiry': '25 jan 2024',
#   'brand': "Kellog's"},
#  '1025': {'name': "Dorito's Nacho Chips",
#   'price': 90,
#   'quan': 360,
#   'expiry': '22 jan 2023',
#   'brand': "Dorito's"},
#  '1026': {'name': 'Thums Up Soft Drink',
#   'price': 40,
#   'quan': 60,
#   'expiry': '20 dec 2024',
#   'brand': 'Thums Up'},
#  '1027': {'name': 'Svami Soda Water',
#   'price': 55,
#   'quan': 70,
#   'expiry': '20 jun 2023',
#   'brand': 'Svami'},
#  '1028': {'name': 'Coca-Cola',
#   'price': 65,
#   'quan': 60,
#   'expiry': '22 jul 2023',
#   'brand': 'Coca Cola'},
#  '1029': {'name': 'Sprite Lime Flavor',
#   'price': 89,
#   'quan': 40,
#   'expiry': '20 nov 2023',
#   'brand': 'Sprite'},
#  '1030': {'name': 'Pepsi Can',
#   'price': 153,
#   'quan': 50,
#   'expiry': '20 oct 2023',
#   'brand': 'Pepsi'},
#  '1031': {'name': 'Tata Salt',
#   'price': 20,
#   'quan': 125,
#   'expiry': '12 jan 2022',
#   'brand': 'Tata'},
#  '1032': {'name': 'Tata Tea Gold',
#   'price': 48,
#   'quan': 145,
#   'expiry': '10 mar 2023',
#   'brand': 'Tata'},
#  '1033': {'name': 'Turmeric Powder',
#   'price': 52,
#   'quan': 122,
#   'expiry': '23 jun 2023',
#   'brand': 'Tata'},
#  '1034': {'name': 'Quaker Oats',
#   'price': 285,
#   'quan': 30,
#   'expiry': '30 oct 2022',
#   'brand': 'Quaker'},
#  '1035': {'name': 'Saffola Active',
#   'price': 207,
#   'quan': 58,
#   'expiry': '29 jan 2022',
#   'brand': 'Saffola'},
#  '1036': {'name': 'Nestle Everyday Ghee',
#   'price': 424,
#   'quan': 30,
#   'expiry': '20 jun 2023',
#   'brand': 'Everyday'}}

# %% [markdown]
# # Update Inventory after products sold

# %%
sales = {1 : {'prod':ui_prod, 'quan':ui_quan, 'amount':products[ui_prod]['price']*ui_quan}}
sal = json.dumps(sales)

fd = open("sales.json",'w')
fd.write(sal)
fd.close()
